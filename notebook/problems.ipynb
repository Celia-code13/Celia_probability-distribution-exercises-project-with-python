# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either head or tails.

# %%
from scipy.stats import binom

# 1) Definimos todas las funciones de probabilidad relacionadas con la DISTRIBUCIÓN BINOMIAL

def dbinom(x, size, prob = 0.5): # Recordamos que aquí este 0.5 es un valor predeterminado, es decir, el valor que aparecerá si no especificamos la probabilidad.
    
    # Con BINOM.PMF vamos a calcular la función de masa de probabilidad (PMF) de una distribución binomial para un valor dado "x", donde "size" es el tamaño de la muestra y "prob" es la probabilidad de éxito de en cada ensayo.
    # El parámetro "loc" no es necesario en una distribución binomial

    result = binom.pmf(k = x, n = size, p = prob, loc = 0)  # Recordar que la x no tiene que ser necesariamente un valor puntual, puede ser un rango de datos, muy útil para plotear.
    return result

def pbinom(q, size, prob = 0.5):

    # Con BINOM.CDF calculamos la función de distribución acumulativa (CDF) de la distribución binomial hasta un valor específico k
    # Representa la acumulación de probabilidades desde el inicio de la distribución hasta el valor k.
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):

    # Con BINOM.PPF calculamos la función cuantil de la distribución binomial.
    # Se supone que la ppf es la función inversa de la CDF. Mientras que la CDF nos da la probabilidad acumulada hasta un valor k/x, la PPF nos da el valor correspondiente para una cierta probabilidad acum.
 
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(k, size, prob = 0.5):

    # Con BINOM.RVS podemos generar variables aleatorias en la distribución binomial. 
    # En este caso, k (primer argumento) es el número de variables que se desea generar.
    result = binom.rvs(n = size, p = prob, size = k)

    return result

# %%
# 2) Aplicamos las distintas funciones con una valores dados comunes (n o size = 10, como número de ensayos, y p = 0.2, como la probabilidad de éxito de cada ensayo) para una distribución binomial.

import numpy as np
np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
# 3) Utilizamos MatplotLib para visualizar la función de masa de probabilidad (PMF), la función de distribución acumulativa (CDF) y la función cuantil (PPF).

import matplotlib.pyplot as plt

np.random.seed(42) # Garantiza que no cambien los números aleatorios generados. El número que se escriba es irrelevante.

size = 10 # n
prob = 0.2 # p
data = rbinom(2000, size = 10, prob = 0.2) # k, aunque ahora no es un valor, si no un intervalo de valores generados aleatoriamente gracias a la función binom.rvs

# Definimos las variables para calcular cada función con los datos aportados anteriormente

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

# Creamos una figura con 3 subgráficos dispuestos verticalmente 

fig, axis = plt.subplots(3, 1, figsize = (5, 7))  # 3 filas y 1 columna

# Seleccionamos cada subgráfico de la lista "axis" y utilizamos stem para hacer gráficos de tallos y hojas, donde "x" son los datos y el eje "y" son los resultados de cada una de las funciones

axis[0].stem(data, pmf, "r-") 
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

plt.tight_layout() # Ajustamos el diseño para que no haya superposiciones

plt.show()

# %% [markdown]
# ## Exercise 1
#
#  Visualizar la función de masa de probabilidad (PMF) de un dado estándar de seis caras.

# %%
import matplotlib.pyplot as plt
import numpy as np


data = np.arange(1, 7)

pmf = [1/6 for _ in data] # La probabilidad de que ocurra cada cara es 1/6, por lo que haremos un bucle para obtener 6 veces el valor 1/6.

plt.figure(figsize = (7, 5))
plt.stem(data, pmf)
plt.title("PMF - Lanzar un dado")
plt.xlabel("Valor del dado")
plt.ylabel("Probabilidad")
plt.xticks(data)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Exercise 2: DISTRIBUCIÓN NORMAL Y UNIFORME
#
#  Realizar los ejercicios anteriores de la distribución binomial, pero utilizando una distribución normal y otra uniforme

# %%
#### DISTRIBUCIÓN NORMAL #### 



from scipy.stats import norm              #Importamos la distribución normal para poder trabajar con ella

# Definición de las funciones:

def pdf_normal (k, mean = 0, std = 1):   

    result = norm.pdf(k, mean, std)       # NORM.PDF calcula la función de densidad de probabilidad (PDF) de una distribución normal.

    return result


def cdf_normal (k, mean = 0, std = 1):    


    result = norm.cdf(k, mean, std)      # NORM.CDF calcula la función de distribución acumulativa (CDF), es decir, representa la acumulación de probabilidades desde el inicio de la distribución hasta el valor k.

    return result

def ppf_normal (k, mean = 0, std = 1):
    
    result = norm.ppf(k, mean, std)  # NORM.CDF calcula la función cuantil de la distribución binomial.
    
    return result


def rvs_normal (k, mean = 0, std = 1):

    result = norm.rvs(k, mean, std)
    
    return result





# Aplicamos las distintas funciones con unos valores dados para una distribución normal:

mean = 10
std = 3


print(f"Probabilidad de que la distribución normal (mean = 10, std = 3) tome el valor 8: {pdf_normal(8, mean, std)}")

print(f"Probabilidad de que la distribución normal (mean = 10, std = 3) tome un valor menor de 8: {cdf_normal(8, mean, std)}")

print(f"Valor para la distribución normal (mean = 10, std = 3) para que la probabilidad acumulativa sea del 0.9: {ppf_normal(0.9, mean, std)}")

print(f"Genera 100 valores aleatorios desde la distribución normal (mean = 10, std = 3): {rvs_normal(1000, mean, std)}")
# Out:
# Probabilidad de que la distribución normal (mean = 10, std = 3) tome el valor 8: 0.10648266850745075
# Probabilidad de que la distribución normal (mean = 10, std = 3) tome un valor menor de 8: 0.2524925375469229
# Valor para la distribución normal (mean = 10, std = 3) para que la probabilidad acumulativa sea del 0.9: 13.844654696633802
# Genera 100 valores aleatorios desde la distribución normal (mean = 10, std = 3): [991.22017413 991.73119646 997.73521108]

# %%
# Por último,  utilizamos MatplotLib para visualizar la función de masa de probabilidad (PMF), la función de distribución acumulativa (CDF) y la función cuantil (PPF) para la distribución normal.

import matplotlib.pyplot as plt
import numpy as np

np.random.seed(56)

mean = 0
std = 1
k = np.arange(-8, 8, 0.02) 


pdf = pdf_normal(k, mean, std)
cdf = cdf_normal(k, mean, std)
ppf = ppf_normal(k, mean, std)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(k, pdf, "r-")
axis[1].plot(k, cdf, "b-")
axis[2].plot(k, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot

# %%
#### DISTRIBUCIÓN UNIFORME #### 

# Definición de funciones 

from scipy.stats import uniform #        Importamos uniform



def pdf_unif(x, loc, scale):             # "loc" indica el inicio del intervalo y "scale" indica la longitud del intervalo.
 
    result = uniform.pdf(x, loc, scale)

    return result


def cdf_unif(x, loc, scale):
   
    result = uniform.cdf(x, loc, scale)

    return result


def ppf_unif(x, loc, scale):


    result = uniform.ppf(x, loc, scale)

    return result


def rvs_unif(x, loc, scale):

  
    result = uniform.rvs(x, loc, scale)

    return result

# %%
# Utilizamos MatplotLib para representar la función de masa de probabilidad (PMF), la función de distribución acumulativa (CDF) y la función cuantil (PPF) para la distribución uniforme.

import matplotlib.pyplot as plt

import numpy as np

np.random.seed(56)

loc = -2
scale = 4
x = np.arange(-5, 5, 0.01)

pdf = pdf_unif(x, loc, scale)
cdf = cdf_unif(x, loc, scale)
ppf = ppf_unif(x, loc, scale)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(x, pdf, "r-")
axis[1].plot(x, cdf, "b-")
axis[2].plot(x, ppf, "g-")

plt.tight_layout()

plt.show()
